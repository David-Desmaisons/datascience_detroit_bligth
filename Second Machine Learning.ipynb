# %%
# %matplotlib inline
from MachineLearning import *
from sklearn.naive_bayes import GaussianNB

clf =  GaussianNB()
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6187826086956522
# precision 0.5963855421686747
# recall 0.5455911823647295
# f1 0.5698587127158556
# Roc 0.6137193986505279
# [[3159 1474]
#  [1814 2178]]
#
# complete
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.5249855072463768
# precision 0.4931524716316682
# recall 0.9471442885771543
# f1 0.6485976498842096
# Roc 0.5541894548864619
# [[ 747 3886]
#  [ 211 3781]]
#
# full
# accuracy 0.5267246376811594
# precision 0.4941860465116279
# recall 0.9581663326653307
# f1 0.6520627344016365
# Roc 0.5565707553678477
# [[ 718 3915]
#  [ 167 3825]]

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6607536231884058
# precision 0.686624649859944
# recall 0.4912324649298597
# f1 0.5727219626168224
# [[3738  895]
#  [2031 1961]]
#
# complete
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6891594202898551
# precision 0.6951473652872879
# recall 0.5849198396793587
# f1 0.6352877159570126
# [[3609 1024]
#  [1657 2335]]
#
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7365797101449275
# precision 0.7937158469945356
# recall 0.5821643286573146
# f1 0.6716763005780346
# [[4029  604]
#  [1668 2324]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier

clf =DecisionTreeClassifier()
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6616811594202898
# precision 0.6834016393442623
# recall 0.50125250501002
# f1 0.5783236994219654
# [[3706  927]
#  [1991 2001]]
#
# complete
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6337391304347826
# precision 0.6048326201862573
# recall 0.6019539078156313
# f1 0.6033898305084746
# [[3063 1570]
#  [1589 2403]]
#
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6762898550724638
# precision 0.6454192922927775
# recall 0.6670841683366734
# f1 0.6560729243656073
# [[3170 1463]
#  [1329 2663]]

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6606376811594203
# precision 0.6806922293858161
# recall 0.5025050100200401
# f1 0.5781812941346015
# [[3692  941]
#  [1986 2006]]
#
# complete
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6914782608695652
# precision 0.7003914483589281
# recall 0.5826653306613226
# f1 0.6361274442773144
# [[3638  995]
#  [1666 2326]]
#
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7373913043478261
# precision 0.7984790874524715
# recall 0.5786573146292585
# f1 0.6710239651416122
# [[4050  583]
#  [1682 2310]]

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(50)
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6615652173913044
# precision 0.6840480274442539
# recall 0.499498997995992
# f1 0.5773852613290864
# [[3712  921]
#  [1998 1994]]
#
# complete
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6969275362318841
# precision 0.7018160515524312
# recall 0.6002004008016032
# f1 0.6470429381582501
# [[3615 1018]
#  [1596 2396]]
#
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7399420289855072
# precision 0.8029095947350191
# recall 0.5806613226452906
# f1 0.673935164994912
# [[4064  569]
#  [1674 2318]]

# %%
from sklearn.linear_model import LogisticRegression

clf =  LogisticRegression()
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6615652173913044
# precision 0.6912655971479501
# recall 0.48572144288577157
# f1 0.5705458290422245
# [[3767  866]
#  [2053 1939]]
#
# complete
# accuracy 0.5481739130434783
# precision 0.5417032484635645
# recall 0.15455911823647295
# f1 0.24049892808419412
# [[4111  522]
#  [3375  617]]
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.5465507246376812
# precision 0.5349439171699741
# recall 0.15531062124248496
# f1 0.240729955348476
# [[4094  539]
#  [3372  620]]

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier(n_iter =20)
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.4944927536231884
# precision 0.463302752293578
# recall 0.5819138276553106
# f1 0.51587830335332
# [[1942 2691]
#  [1669 2323]]
#
# complete
# accuracy 0.5234782608695652
# precision 0.4795847750865052
# recall 0.3471943887775551
# f1 0.4027898866608544
# [[3129 1504]
#  [2606 1386]]
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.5370434782608695
# precision 0.4444444444444444
# recall 0.001002004008016032
# f1 0.0019995001249687575
# [[4628    5]
#  [3988    4]]

# %%
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors=9)
diplayPredictor(clf)
# Out:
# basic
# accuracy 0.6215652173913043
# precision 0.6216577540106952
# recall 0.46593186372745493
# f1 0.5326460481099657
# [[3501 1132]
#  [2132 1860]]
#
# complete
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.5628985507246377
# precision 0.5312676056338028
# recall 0.4724448897795591
# f1 0.5001325908247148
# [[2969 1664]
#  [2106 1886]]
#
# full
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.5574492753623188
# precision 0.5243664717348928
# recall 0.4716933867735471
# f1 0.4966372148226296
# [[2925 1708]
#  [2109 1883]]

# %%
def getalldata2(dataset):
    con = sqlite3.connect("./data/location.s3db")
    alldata = pd.read_sql_query("SELECT BlightViolationNumber, Call311Number, AmbientCrime6-AmbientCrime7 as acr7, AmbientCrime7, AmbientCall6-AmbientCall7 as acl7, AmbientCall7, AmbientViolation6-AmbientViolation7 as av7, AmbientViolation7, Demolished from {} order by random()".format(dataset), con)
    parameters = alldata.as_matrix(['BlightViolationNumber', 'Call311Number', 'AmbientCrime6', 'acr7', 'AmbientCall6', 'acl7', 'AmbientViolation6', 'av7'])
    normalized = normalize(parameters, norm='l2')
    return con, normalized, alldata.as_matrix(['Demolished']).reshape(len(alldata))

def checkNewPrediction(clf):
    checkPredictionFromFactory(clf, lambda : getalldata2('Newdata'))

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
checkNewPrediction(clf)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6739710144927537
# precision 0.6731220657276995
# recall 0.5746492985971944
# f1 0.62
# [[3519 1114]
#  [1698 2294]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier

clf =DecisionTreeClassifier()
checkNewPrediction(clf)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6201739130434782
# precision 0.5884824518042511
# recall 0.5964428857715431
# f1 0.5924359293356556
# [[2968 1665]
#  [1611 2381]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier

classification = [DecisionTreeClassifier(), RandomForestClassifier(),  LogisticRegression(), KNeighborsClassifier(), SGDClassifier() ]

BenchMarks(classification)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

clf = DecisionTreeClassifier()
dodisplayfull(clf)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6845217391304348
# precision 0.653836843379327
# recall 0.6766032064128257
# f1 0.6650252369814108
# [[3203 1430]
#  [1291 2701]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

con, x, y  = getafulldata('Newdata')
clf = DecisionTreeClassifier()
clf.fit(x,y)
con.close()
clf.feature_importances_
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# array([ 0.19303679,  0.1100344 ,  0.1178767 ,  0.08819654,  0.074476  ,
#         0.021544  ,  0.05065205,  0.09150986,  0.09957171,  0.08869212,
#         0.06440982])

# %%
feature = ['BlightViolationNumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'AmbientCall8', 'call7', 'call6', 'AmbientViolation8', 'v7', 'v6']

# %%
features = zip(feature, clf.feature_importances_)
features = [f for f in features]
features
# Out:
# [('BlightViolationNumber', 0.19303679047588104),
#  ('Call311Number', 0.11003440407879046),
#  ('AmbientCrime8', 0.11787670011850952),
#  ('crime7', 0.088196540554942693),
#  ('crime6', 0.074475999201449761),
#  ('AmbientCall8', 0.02154399868794387),
#  ('call7', 0.050652049432519386),
#  ('call6', 0.091509864742953556),
#  ('AmbientViolation8', 0.099571706922380571),
#  ('v7', 0.088692120966235757),
#  ('v6', 0.064409824818393274)]

# %%
def dataGetter2(dataset):
    con = sqlite3.connect("./data/location.s3db")
    alldata = pd.read_sql_query("SELECT BlightViolationNumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6, AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished from {} order by random()".format(dataset), con)
    parameters = alldata.as_matrix(['BlightViolationNumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'AmbientCall6', 'AmbientViolation8', 'v7', 'v6'])
    normalized = normalize(parameters, norm='l2')
    return con, normalized, alldata.as_matrix(['Demolished']).reshape(len(alldata))

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter2('NewData'))
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6860289855072463
# precision 0.6562804284323271
# recall 0.6753507014028056
# f1 0.665679012345679
# [[3221 1412]
#  [1296 2696]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6883478260869565
# precision 0.6640664318067439
# recall 0.6610721442885772
# f1 0.6625659050966608
# [[3298 1335]
#  [1353 2639]]

# %%
def dataGetter3(dataset):
    con = sqlite3.connect("./data/location.s3db")
    query = ("select BlightViolationNumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from {} left outer join UnpayedViolationByHouse "
            "on  NewData.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewData.StreetName =UnpayedViolationByHouse.StreetName order by random()")
    alldata = pd.read_sql_query(query.format(dataset), con)
    parameters = alldata.as_matrix(['BlightViolationNumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'AmbientCall8', 'call7', 'call6', 'AmbientViolation8', 'v7', 'v6', 'Unpayed'])
    normalized = normalize(parameters, norm='l2')
    return con, parameters, alldata.as_matrix(['Demolished']).reshape(len(alldata))

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter3('NewData'))
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6809275362318841
# precision 0.6549225387306347
# recall 0.656563126252505
# f1 0.6557418063547661
# [[3252 1381]
#  [1371 2621]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6820869565217391
# precision 0.6507477086348288
# recall 0.6758517034068137
# f1 0.6630621774391743
# [[3185 1448]
#  [1294 2698]]

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter3('NewData'))
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7363478260869565
# precision 0.7921768707482993
# recall 0.5834168336673347
# f1 0.6719561454125793
# [[4022  611]
#  [1663 2329]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7292753623188406
# precision 0.7798041202296522
# recall 0.5784068136272545
# f1 0.6641737379548397
# [[3981  652]
#  [1683 2309]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

con, x, y  = dataGetter3('Newdata')
clf = DecisionTreeClassifier()
clf.fit(x,y)
con.close()
clf.feature_importances_
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# array([ 0.12549305,  0.11218167,  0.10696023,  0.05937424,  0.11219931,
#         0.02083395,  0.03333806,  0.09172581,  0.07947793,  0.09758186,
#         0.1278533 ,  0.03298059])

# %%
def dataGetter4(dataset):
    con = sqlite3.connect("./data/location.s3db")
    query = ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from {} left outer join UnpayedViolationByHouse "
            "on  NewData.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewData.StreetName =UnpayedViolationByHouse.StreetName order by random()")
    alldata = pd.read_sql_query(query.format(dataset), con)
    parameters = alldata.as_matrix(['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'AmbientCall8', 'call7', 'call6', 'AmbientViolation8', 'v7', 'v6', 'Unpayed'])
    normalized = normalize(parameters, norm='l2')
    return con, parameters, alldata.as_matrix(['Demolished']).reshape(len(alldata))

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter4('NewData'))
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6856811594202898
# precision 0.6570237803383182
# recall 0.6713426853707415
# f1 0.6641060587287821
# [[3234 1399]
#  [1312 2680]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6831304347826087
# precision 0.6551639142223318
# recall 0.6658316633266533
# f1 0.6604547148714127
# [[3234 1399]
#  [1334 2658]]

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter4('NewData'))
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7387826086956522
# precision 0.7946458827516096
# recall 0.5874248496993988
# f1 0.6755005041048538
# [[4027  606]
#  [1647 2345]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7326376811594203
# precision 0.7853757616790792
# recall 0.5811623246492986
# f1 0.6680103656780881
# [[3999  634]
#  [1672 2320]]

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter4('NewData'), lambda : dataGetter3('NewData'))
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7285797101449275
# precision 0.7845570492933471
# recall 0.5701402805611222
# f1 0.6603800957493109
# [[4008  625]
#  [1716 2276]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7297391304347826
# precision 0.7816208884367583
# recall 0.5774048096192385
# f1 0.664169428036306
# [[3989  644]
#  [1687 2305]]

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter4('NewData'))
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7384347826086957
# precision 0.7930452397029034
# recall 0.5884268537074149
# f1 0.6755823986194996
# [[4020  613]
#  [1643 2349]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7306666666666667
# precision 0.7847151142954623
# recall 0.5761523046092184
# f1 0.6644518272425249
# [[4002  631]
#  [1692 2300]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

con, x, y  = dataGetter4('Newdata')
clf = DecisionTreeClassifier()
clf.fit(x,y)
con.close()
clf.feature_importances_
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# array([ 0.09753943,  0.09179662,  0.10510278,  0.06041699,  0.11412608,
#         0.01252481,  0.03019097,  0.08773915,  0.09489476,  0.09944374,
#         0.13143327,  0.07479139])

# %%
def dataGetter5(dataset):
    con = sqlite3.connect("./data/location.s3db")
    query = ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
             "TRAFFICVIOLATIONS1G8,ASSAULTG8,LARCENYG8,DAMAGETOPROPERTYG8,AGGRAVATEDASSAULTG8,BURGLARYG8,STOLENVEHICLEG8,TRAFFICVIOLATIONS2G8,"
             "FRAUDG8,ROBBERYG8,DANGEROUSDRUGSG8,OBSTRUCTINGJUDICIARYG8,WEAPONSOFFENSESG8, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from {} left outer join UnpayedViolationByHouse "
            "on  NewData.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewData.StreetName =UnpayedViolationByHouse.StreetName order by random()")
    alldata = pd.read_sql_query(query.format(dataset), con)
    parameters = alldata.as_matrix(['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 
                                    'TRAFFICVIOLATIONS1G8','ASSAULTG8','LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8',
                                    'STOLENVEHICLEG8','TRAFFICVIOLATIONS2G8','FRAUDG8','ROBBERYG8','DANGEROUSDRUGSG8','OBSTRUCTINGJUDICIARYG8','WEAPONSOFFENSESG8',
                                    'AmbientCall8', 'call7', 'call6', 'AmbientViolation8', 'v7', 'v6', 'Unpayed'])
    normalized = normalize(parameters, norm='l2')
    return con, parameters, alldata.as_matrix(['Demolished']).reshape(len(alldata))

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter5('NewData'))
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7298550724637681
# precision 0.7871458189357291
# recall 0.5706412825651302
# f1 0.661632297415045
# [[4017  616]
#  [1714 2278]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.736
# precision 0.7953840854288667
# recall 0.5784068136272545
# f1 0.6697606961566354
# [[4039  594]
#  [1683 2309]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter5('NewData'))
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6765217391304348
# precision 0.646871945259042
# recall 0.6630761523046093
# f1 0.6548738248391885
# [[3188 1445]
#  [1345 2647]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.680463768115942
# precision 0.6519174041297935
# recall 0.6643286573146293
# f1 0.6580645161290323
# [[3217 1416]
#  [1340 2652]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

con, x, y  = dataGetter5('Newdata')
clf = DecisionTreeClassifier()
clf.fit(x,y)
con.close()
clf.feature_importances_
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# array([ 0.09649764,  0.09214323,  0.10182901,  0.0615379 ,  0.10965019,
#         0.00661711,  0.00417965,  0.00417005,  0.00121736,  0.00155935,
#         0.00121491,  0.00380642,  0.00277285,  0.00050996,  0.0025462 ,
#         0.00157733,  0.        ,  0.00067609,  0.01236988,  0.03542921,
#         0.08585437,  0.08654458,  0.09390664,  0.12138658,  0.0720035 ])

# %%
para =['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 
                                    'TRAFFICVIOLATIONS1G8','ASSAULTG8','LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8',
                                    'STOLENVEHICLEG8','TRAFFICVIOLATIONS2G8','FRAUDG8','ROBBERYG8','DANGEROUSDRUGSG8','OBSTRUCTINGJUDICIARYG8','WEAPONSOFFENSESG8',
                                    'AmbientCall8', 'call7', 'call6', 'AmbientViolation8', 'v7', 'v6', 'Unpayed']

# %%
features = zip(para, clf.feature_importances_)
features = [f for f in features]
features
# Out:
# [('bnumber', 0.096497637777513953),
#  ('Call311Number', 0.092143230260224487),
#  ('AmbientCrime8', 0.10182900819574225),
#  ('crime7', 0.061537898955304461),
#  ('crime6', 0.10965018699686975),
#  ('TRAFFICVIOLATIONS1G8', 0.0066171127631607669),
#  ('ASSAULTG8', 0.004179650191473201),
#  ('LARCENYG8', 0.0041700501345195524),
#  ('DAMAGETOPROPERTYG8', 0.0012173612254083364),
#  ('AGGRAVATEDASSAULTG8', 0.0015593505094443165),
#  ('BURGLARYG8', 0.0012149063572846981),
#  ('STOLENVEHICLEG8', 0.0038064234813770547),
#  ('TRAFFICVIOLATIONS2G8', 0.0027728469579637407),
#  ('FRAUDG8', 0.00050995768993760608),
#  ('ROBBERYG8', 0.0025462015189488566),
#  ('DANGEROUSDRUGSG8', 0.0015773268099395213),
#  ('OBSTRUCTINGJUDICIARYG8', 0.0),
#  ('WEAPONSOFFENSESG8', 0.00067609088386244305),
#  ('AmbientCall8', 0.012369884222047236),
#  ('call7', 0.03542920757780961),
#  ('call6', 0.085854366837008422),
#  ('AmbientViolation8', 0.086544579188003332),
#  ('v7', 0.09390664012468751),
# ...

# %%
def dataGetter6(dataset):
    con = sqlite3.connect("./data/location.s3db")
    query = ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
             "TRAFFICVIOLATIONS1G8,ASSAULTG8,LARCENYG8,DAMAGETOPROPERTYG8,AGGRAVATEDASSAULTG8,BURGLARYG8,STOLENVEHICLEG8,TRAFFICVIOLATIONS2G8,"
             "ROBBERYG8,DANGEROUSDRUGSG8, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from {} left outer join UnpayedViolationByHouse "
            "on  NewData.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewData.StreetName =UnpayedViolationByHouse.StreetName order by random()")
    alldata = pd.read_sql_query(query.format(dataset), con)
    parameters = alldata.as_matrix(['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 
                                    'TRAFFICVIOLATIONS1G8','ASSAULTG8','LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8',
                                    'STOLENVEHICLEG8','TRAFFICVIOLATIONS2G8','ROBBERYG8','DANGEROUSDRUGSG8',
                                    'AmbientCall8', 'call7', 'call6', 'AmbientViolation8', 'v7', 'v6', 'Unpayed'])
    normalized = normalize(parameters, norm='l2')
    return con, parameters, alldata.as_matrix(['Demolished']).reshape(len(alldata))

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter6('NewData'))
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6866086956521739
# precision 0.6566982737661075
# recall 0.6766032064128257
# f1 0.6665021591610117
# [[3221 1412]
#  [1291 2701]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6828985507246377
# precision 0.6530314097881665
# recall 0.6718436873747495
# f1 0.6623039881466848
# [[3208 1425]
#  [1310 2682]]

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
BenchMarksdatagetter(clf, lambda : dataGetter6('NewData'))
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7293913043478261
# precision 0.7904695164681149
# recall 0.5651302605210421
# f1 0.6590709903593339
# [[4035  598]
#  [1736 2256]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7325217391304348
# precision 0.7876408330488222
# recall 0.5779058116232465
# f1 0.6666666666666666
# [[4011  622]
#  [1685 2307]]

# %%
class NewFullExtractor(DataExtractor):
    def getparameters(self):
        return ['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'TRAFFICVIOLATIONS1G8','ASSAULTG8',
                'LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8', 'STOLENVEHICLEG8',
                'TRAFFICVIOLATIONS2G8','ROBBERYG8','DANGEROUSDRUGSG8', 'AmbientCall8', 'call7', 'call6', 
                'AmbientViolation8', 'v7', 'v6', 'Unpayed']
    
    def getquery(self):
        return ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
             "TRAFFICVIOLATIONS1G8,ASSAULTG8,LARCENYG8,DAMAGETOPROPERTYG8,AGGRAVATEDASSAULTG8,BURGLARYG8,STOLENVEHICLEG8,TRAFFICVIOLATIONS2G8,"
             "ROBBERYG8,DANGEROUSDRUGSG8, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from NewData left outer join UnpayedViolationByHouse "
            "on  NewData.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewData.StreetName =UnpayedViolationByHouse.StreetName order by random()")

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
extract = NewFullExtractor()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7304347826086957
# precision 0.7883085437564856
# recall 0.5708917835671342
# f1 0.6622112450966149
# [[4021  612]
#  [1713 2279]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7253333333333334
# precision 0.7753647777400746
# recall 0.5723947895791583
# f1 0.6585963395301918
# [[3971  662]
#  [1707 2285]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *


def getparameters(dataextractor):
    con, x, y  = dataextractor.getdata()
    clf = DecisionTreeClassifier()
    clf.fit(x,y)
    con.close()
    return [z for z in zip(clf.feature_importances_, dataextractor.getparameters())]

# %%
extract = NewFullExtractor()
getparameters(extract)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# [(0.10369472165876921, 'bnumber'),
#  (0.091420093642647013, 'Call311Number'),
#  (0.11389128265765407, 'AmbientCrime8'),
#  (0.072182285187711789, 'crime7'),
#  (0.058337877201348858, 'crime6'),
#  (0.0090551896690660352, 'TRAFFICVIOLATIONS1G8'),
#  (0.0045496047494699805, 'ASSAULTG8'),
#  (0.0052585318612547718, 'LARCENYG8'),
#  (0.0034154530774938062, 'DAMAGETOPROPERTYG8'),
#  (0.0024706807107083752, 'AGGRAVATEDASSAULTG8'),
#  (0.002338606682352808, 'BURGLARYG8'),
#  (0.0040439887765383303, 'STOLENVEHICLEG8'),
#  (0.0035032946033059374, 'TRAFFICVIOLATIONS2G8'),
#  (0.0023519318712934062, 'ROBBERYG8'),
#  (0.00084383812344436841, 'DANGEROUSDRUGSG8'),
#  (0.016124014415044068, 'AmbientCall8'),
#  (0.046681020861308056, 'call7'),
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *


def BenchMarkRandom(extract):
    clf = RandomForestClassifier()
    BenchMarksdatagetter(clf, lambda : extract.getdata())

# %%
class ExtractorWithZipCode(DataExtractor):
    def getparameters(self):
        return ['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'TRAFFICVIOLATIONS1G8','ASSAULTG8',
                'LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8', 'STOLENVEHICLEG8',
                'TRAFFICVIOLATIONS2G8','ROBBERYG8','DANGEROUSDRUGSG8', 'AmbientCall8', 'call7', 'call6', 
                'PersonsPerHousehold', 'MedianHouseValue', 'IncomePerHousehold', 'PercentageFamilyHouseholds', 'PercentageBelowPoverty',  
                'PercentageBelow50Poverty', 'PercentageRenters', 'UnemployedPercentage',  'PercentageWhitePopulation',  
                'AmbientViolation8', 'v7', 'v6', 'Unpayed']
    
    def getquery(self):
        return ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
             "TRAFFICVIOLATIONS1G8,ASSAULTG8,LARCENYG8,DAMAGETOPROPERTYG8,AGGRAVATEDASSAULTG8,BURGLARYG8,STOLENVEHICLEG8,TRAFFICVIOLATIONS2G8,"
             "ROBBERYG8,DANGEROUSDRUGSG8, PersonsPerHousehold, MedianHouseValue, IncomePerHousehold, "
             "PercentageFamilyHouseholds, PercentageBelowPoverty,  PercentageBelow50Poverty, PercentageRenters, UnemployedPercentage,  "
             "(100 * WhitePopulation)/(BlackPopulation+WhitePopulation) as PercentageWhitePopulation, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from NewdataZip left outer join UnpayedViolationByHouse "
            "on  NewdataZip.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewdataZip.StreetName =UnpayedViolationByHouse.StreetName order by random()")

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

clf = RandomForestClassifier()
extract = ExtractorWithZipCode()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7380869565217392
# precision 0.7723986167871738
# recall 0.6154809619238477
# f1 0.685069008782936
# [[3909  724]
#  [1535 2457]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7321739130434782
# precision 0.7906012439530062
# recall 0.5731462925851704
# f1 0.6645367412140575
# [[4027  606]
#  [1704 2288]]

# %%
from sklearn.ensemble import RandomForestClassifier
from MachineLearning import *

def displayRandom(extract, extract2=None):
    clf = RandomForestClassifier()
    dataextract2 = None
    if extract2 is not None:
        dataextract2 = lambda : extract2.getdata()
    BenchMarksdatagetter(clf, lambda : extract.getdata(), dataextract2)

# %%
extract = ExtractorWithZipCode()
displayRandom(extract)
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7383188405797101
# precision 0.7701650576144503
# recall 0.6194889779559118
# f1 0.6866583368041094
# [[3895  738]
#  [1519 2473]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7320579710144928
# precision 0.7855929323819232
# recall 0.5791583166332666
# f1 0.66676279740447
# [[4002  631]
#  [1680 2312]]

# %%
extract = ExtractorWithZipCode()
getparameters(extract)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# [(0.096271631236251001, 'bnumber'),
#  (0.090918827584135775, 'Call311Number'),
#  (0.10273121314698816, 'AmbientCrime8'),
#  (0.059661698307075059, 'crime7'),
#  (0.063108361091878451, 'crime6'),
#  (0.0088983686628125724, 'TRAFFICVIOLATIONS1G8'),
#  (0.0063884503435577954, 'ASSAULTG8'),
#  (0.0037050717148121863, 'LARCENYG8'),
#  (0.0014964049296590412, 'DAMAGETOPROPERTYG8'),
#  (0.0033589742525003026, 'AGGRAVATEDASSAULTG8'),
#  (0.0029501661470461038, 'BURGLARYG8'),
#  (0.0030627129550319702, 'STOLENVEHICLEG8'),
#  (0.0015567372215932588, 'TRAFFICVIOLATIONS2G8'),
#  (0.0012193214554736295, 'ROBBERYG8'),
#  (0.0011552110600141048, 'DANGEROUSDRUGSG8'),
#  (0.013143982940712673, 'AmbientCall8'),
#  (0.029577889437358951, 'call7'),
# ...

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

extract = ExtractorWithZipCode()
clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6968115942028985
# precision 0.6673960612691466
# recall 0.687625250501002
# f1 0.6773596545342381
# [[3265 1368]
#  [1247 2745]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6857971014492754
# precision 0.659452736318408
# recall 0.6640781563126252
# f1 0.6617573639540688
# [[3264 1369]
#  [1341 2651]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

extract = ExtractorWithZipCode('l1')
clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6979710144927537
# precision 0.6731585518102372
# recall 0.6753507014028056
# f1 0.6742528448168063
# [[3324 1309]
#  [1296 2696]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6809275362318841
# precision 0.6524840137727497
# recall 0.6645791583166333
# f1 0.6584760486473071
# [[3220 1413]
#  [1339 2653]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

extract = ExtractorWithZipCode()
clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6995942028985507
# precision 0.6727496917385943
# recall 0.6833667334669339
# f1 0.67801665216851
# [[3306 1327]
#  [1264 2728]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6840579710144927
# precision 0.657001239157373
# recall 0.6640781563126252
# f1 0.6605207424940824
# [[3249 1384]
#  [1341 2651]]

# %%
class ExtractorWithZipCodeAndPopulation(DataExtractor):
    def getparameters(self):
        return ['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'TRAFFICVIOLATIONS1G8','ASSAULTG8',
                'LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8', 'STOLENVEHICLEG8',
                'TRAFFICVIOLATIONS2G8','ROBBERYG8','DANGEROUSDRUGSG8', 'AmbientCall8', 'call7', 'call6', 
                'PersonsPerHousehold', 'MedianHouseValue', 'IncomePerHousehold', 'PercentageFamilyHouseholds', 'PercentageBelowPoverty',  
                'PercentageBelow50Poverty', 'PercentageRenters', 'UnemployedPercentage',  'PercentageWhitePopulation',  
                'AmbientViolation8', 'v7', 'v6', 'Unpayed', 'PercentagePopulation']
    
    def getquery(self):
        return ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
             "TRAFFICVIOLATIONS1G8,ASSAULTG8,LARCENYG8,DAMAGETOPROPERTYG8,AGGRAVATEDASSAULTG8,BURGLARYG8,STOLENVEHICLEG8,TRAFFICVIOLATIONS2G8,"
             "ROBBERYG8,DANGEROUSDRUGSG8, PersonsPerHousehold, MedianHouseValue, IncomePerHousehold, (Population2010 - Population2000) * 100 / Population2010 as PercentagePopulation, "
             "PercentageFamilyHouseholds, PercentageBelowPoverty,  PercentageBelow50Poverty, PercentageRenters, UnemployedPercentage,  "
             "(100 * WhitePopulation)/(BlackPopulation+WhitePopulation) as PercentageWhitePopulation, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from NewdataZip left outer join UnpayedViolationByHouse "
            "on  NewdataZip.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewdataZip.StreetName =UnpayedViolationByHouse.StreetName order by random()")

# %%
extract = ExtractorWithZipCodeAndPopulation('l1')
displayRandom(extract)
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7324057971014493
# precision 0.7581238503985285
# recall 0.6194889779559118
# f1 0.6818307140887787
# [[3844  789]
#  [1519 2473]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7328695652173913
# precision 0.7902338376891335
# recall 0.5756513026052105
# f1 0.6660869565217392
# [[4023  610]
#  [1694 2298]]

# %%
extract = ExtractorWithZipCodeAndPopulation()
getparameters(extract)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# [(0.095649612340147266, 'bnumber'),
#  (0.091313828114524973, 'Call311Number'),
#  (0.10402773576158074, 'AmbientCrime8'),
#  (0.056866603918065757, 'crime7'),
#  (0.063015962669859968, 'crime6'),
#  (0.0066299699351592863, 'TRAFFICVIOLATIONS1G8'),
#  (0.0035523015706628372, 'ASSAULTG8'),
#  (0.002487716508945166, 'LARCENYG8'),
#  (0.0017683028619730409, 'DAMAGETOPROPERTYG8'),
#  (0.0024472169130261645, 'AGGRAVATEDASSAULTG8'),
#  (0.0019180479785045066, 'BURGLARYG8'),
#  (0.0022880871556941393, 'STOLENVEHICLEG8'),
#  (0.0012930595095025155, 'TRAFFICVIOLATIONS2G8'),
#  (0.00042059211404821842, 'ROBBERYG8'),
#  (0.00071248251891071687, 'DANGEROUSDRUGSG8'),
#  (0.012923482129706971, 'AmbientCall8'),
#  (0.029787027748679966, 'call7'),
# ...

# %%
-

# %%
extract = ExtractorWithZipCodeAndPopulationAndAge()
displayRandom(extract)
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7397101449275363
# precision 0.7686865579821593
# recall 0.626002004008016
# f1 0.6900455612315339
# Roc 0.73184408424014
# [[3881  752]
#  [1493 2499]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7314782608695652
# precision 0.7879725085910653
# recall 0.5743987975951904
# f1 0.6644450883801797
# Roc 0.7206118745152728
# [[4016  617]
#  [1699 2293]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

extract = ExtractorWithZipCodeAndPopulationAndAge()
clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6956521739130435
# precision 0.6711745554720762
# recall 0.6713426853707415
# f1 0.6712586098935504
# [[3320 1313]
#  [1312 2680]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.680695652173913
# precision 0.654364089775561
# recall 0.657314629258517
# f1 0.6558360409897525
# [[3247 1386]
#  [1368 2624]]

# %%
extract = ExtractorWithZipCodeAndPopulationAndAge()
getparameters(extract)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# [(0.099475546208962637, 'bnumber'),
#  (0.091629634297812915, 'Call311Number'),
#  (0.10448932083694723, 'AmbientCrime8'),
#  (0.053385067990269652, 'crime7'),
#  (0.062318488402462686, 'crime6'),
#  (0.0060595083729540564, 'TRAFFICVIOLATIONS1G8'),
#  (0.0041617019784806579, 'ASSAULTG8'),
#  (0.0051548769081478339, 'LARCENYG8'),
#  (0.0015117502509141125, 'DAMAGETOPROPERTYG8'),
#  (0.0032692371386023964, 'AGGRAVATEDASSAULTG8'),
#  (0.00097134021715870021, 'BURGLARYG8'),
#  (0.0030506974273234871, 'STOLENVEHICLEG8'),
#  (0.0010197205976495709, 'TRAFFICVIOLATIONS2G8'),
#  (0.00082086576848058054, 'ROBBERYG8'),
#  (0.0014741903429744403, 'DANGEROUSDRUGSG8'),
#  (0.012664665697159447, 'AmbientCall8'),
#  (0.027930751715972389, 'call7'),
# ...

# %%
class ExtractorWithZipCodeAndPopulationAndAgeScale(DataExtractorScaler):
    def getparameters(self):
        return ['bnumber', 'Call311Number', 'AmbientCrime8', 'crime7', 'crime6', 'TRAFFICVIOLATIONS1G8','ASSAULTG8',
                'LARCENYG8','DAMAGETOPROPERTYG8','AGGRAVATEDASSAULTG8','BURGLARYG8', 'STOLENVEHICLEG8',
                'TRAFFICVIOLATIONS2G8','ROBBERYG8','DANGEROUSDRUGSG8', 'AmbientCall8', 'call7', 'call6', 
                'PersonsPerHousehold', 'MedianHouseValue', 'IncomePerHousehold', 'PercentageFamilyHouseholds', 'PercentageBelowPoverty',  
                'PercentageBelow50Poverty', 'PercentageRenters', 'UnemployedPercentage',  'PercentageWhitePopulation',  'MedianAge',
                'AmbientViolation8', 'v7', 'v6', 'Unpayed', 'PercentagePopulation']
    
    def getquery(self):
        return ("select BlightViolationNumber - coalesce(UnpayedViolationByHouse.Count,0) as bnumber, Call311Number, AmbientCrime8, AmbientCrime7 - AmbientCrime8 as crime7, "
            "AmbientCrime6 - AmbientCrime7 as crime6, AmbientCall8, AmbientCall6 - AmbientCall7 as call6, AmbientCall7- AmbientCall8 as call7, "
            "AmbientViolation8, AmbientViolation7 - AmbientViolation8 as v7, AmbientViolation6 - AmbientViolation7 as v6, Demolished, "
             "TRAFFICVIOLATIONS1G8,ASSAULTG8,LARCENYG8,DAMAGETOPROPERTYG8,AGGRAVATEDASSAULTG8,BURGLARYG8,STOLENVEHICLEG8,TRAFFICVIOLATIONS2G8,"
             "ROBBERYG8,DANGEROUSDRUGSG8, PersonsPerHousehold, MedianHouseValue, IncomePerHousehold, (Population2010 - Population2000) * 100 / Population2010 as PercentagePopulation, "
             "PercentageFamilyHouseholds, PercentageBelowPoverty,  PercentageBelow50Poverty, PercentageRenters, UnemployedPercentage,MedianAge,  "
             "(100 * WhitePopulation)/(BlackPopulation+WhitePopulation) as PercentageWhitePopulation, "
            "coalesce(UnpayedViolationByHouse.Count,0) as Unpayed  from NewdataZip left outer join UnpayedViolationByHouse "
            "on  NewdataZip.StreetNumber=UnpayedViolationByHouse.StreetNumber and  NewdataZip.StreetName =UnpayedViolationByHouse.StreetName order by random()")

# %%
extract = ExtractorWithZipCodeAndPopulationAndAge('l1')
extract2 = ExtractorWithZipCodeAndPopulationAndAgeScale()
displayRandom(extract, extract2)
# Out:
# First Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7327536231884058
# precision 0.7630183972560025
# recall 0.6129759519038076
# f1 0.6798166412001667
# [[3873  760]
#  [1545 2447]]
#
# Second Option RandomForestClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7349565217391304
# precision 0.7665625
# recall 0.6144789579158316
# f1 0.682146829810901
# [[3886  747]
#  [1539 2453]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from MachineLearning import *

extract = ExtractorWithZipCodeAndPopulationAndAge()
clf = DecisionTreeClassifier()
BenchMarksdatagetter(clf, lambda : extract.getdata())
# Out:
# First Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7045797101449275
# precision 0.6767874632713027
# recall 0.6923847695390781
# f1 0.6844972758791481
# Roc 0.7037360929499837
# [[3313 1320]
#  [1228 2764]]
#
# Second Option DecisionTreeClassifier
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.6787246376811594
# precision 0.6475707034082668
# recall 0.6710921843687375
# f1 0.6591216631812031
# Roc 0.6781966425836781
# [[3175 1458]
#  [1313 2679]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier

classification = [DecisionTreeClassifier(), RandomForestClassifier(),  LogisticRegression(), KNeighborsClassifier(), SGDClassifier() ]
extract = ExtractorWithZipCodeAndPopulationAndAge()
BenchMarks(classification, lambda : extract.getdata())
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier

classification = [DecisionTreeClassifier(), RandomForestClassifier(),  GradientBoostingClassifier(), LogisticRegression(), KNeighborsClassifier(), SGDClassifier() ]
BenchMarks(classification)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
extract = ExtractorWithZipCodeAndPopulationAndAge()
clf = GradientBoostingClassifier()
dodisplay('', clf, lambda : extract.getdata())
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# accuracy 0.7559420289855072
# precision 0.84472049689441
# recall 0.5791583166332666
# f1 0.6871749145489672
# Roc 0.7437125492080643
# [[4208  425]
#  [1680 2312]]

# %%
from sklearn.tree import DecisionTreeClassifier as DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier

extract = ExtractorWithZipCodeAndPopulationAndAge()
classification = [DecisionTreeClassifier(), RandomForestClassifier(), AdaBoostClassifier(), GradientBoostingClassifier(), LogisticRegression(), KNeighborsClassifier(), SGDClassifier() ]
BenchMarks(classification, lambda : extract.getdata())
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the normalize function.
#   warnings.warn(msg, DataConversionWarning)
# ...
