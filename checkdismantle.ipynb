# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import sqlite3


blight_violations = pd.read_csv('./data/Demolition_Permits_digested_withbb.csv',  low_memory=False)
blight_violations
# Out:
#       Unnamed: 0      PERMIT_NO PERMIT_APPLIED PERMIT_ISSUED PERMIT_EXPIRES  \
# 0              0  BLD2015-03955        8/28/15       8/28/15            NaN
# 1              1  BLD2015-04083        8/28/15       8/28/15            NaN
# 2              2  BLD2015-03976        8/28/15       8/28/15            NaN
# 3              3  BLD2015-03781        8/28/15       8/28/15            NaN
# 4              4  BLD2015-03677        8/28/15       8/28/15            NaN
# 5              5  BLD2015-03914        8/28/15       8/28/15            NaN
# 6              6  BLD2015-03950        8/28/15       8/28/15            NaN
# 7              7  BLD2015-03953        8/28/15       8/28/15            NaN
# 8              8  BLD2015-03945        8/28/15       8/28/15            NaN
# 9              9  BLD2015-03821        8/28/15       8/28/15            NaN
# 10            10  BLD2015-03900        8/28/15       8/28/15            NaN
# ...

# %%
count = 0
for index, row in blight_violations.iterrows():
    dis = row['BLD_PERMIT_TYPE']
    if dis=='Dismantle' or dis=='DISM':
        count+=1

print(index, count)
# Out:
# 7132 7133
